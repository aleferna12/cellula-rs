# %%
import polars as pl
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import colorir as cl
import numpy as np
from pathlib import Path
import analyses.calculate_adh as adh
from analyses import io
import analyses.phylogeny as phy
from tqdm import tqdm

# %%
colors = cl.StackPalette.load("carnival")
colors2 = cl.StackPalette.load("safe")
colors2[0], colors2[2] = colors2[4], colors2[0]

# %%
cdf1 = io.read_celldfs(
    "../runs/evo/", 
    levels=["replica"], 
    low_memory=True, 
    scan=True
).filter(pl.col("wtime") <= 200e6)
#cdf2 = io.read_celldfs("../runs/evo2_2/", levels=["replica"]).filter(pl.col("wtime") <= 200e6)
celldf = (
    cdf1
        .with_columns(
            replica=pl.col("replica").cast(pl.UInt32)
        )
        .sort(["replica", "wtime"])
).collect()
celldf

# %%
# Global gamma:
wtimes = celldf["wtime"].sort().diff()
wtime = wtimes.filter(wtimes != 0).mean()
selectors = ["index", "ligands", "receptors"]
gammadfs = []
meangammadfs = []
groupped = (
    celldf
        .filter((pl.col("wtime") - wtime) % 2e6 == 0)  # Values only change between seasons of 2e6 steps
        .sort("replica", "wtime")
        .group_by(["replica", "wtime"])
)
for (replica, time), group in tqdm(groupped):
    sel_group = group.select(selectors)
    lig_recep = sel_group.join(sel_group, how="cross")
    gammas = adh.calculate_gamma(
        20, 
        adh.cell_contact_energy(
            *lig_recep.select(pl.exclude("index", "index_right")).to_numpy().T,
            20,
            32,
            8
        )
    )
    means = lig_recep.with_columns(gamma=gammas).group_by("index").agg(
        mean_gamma=pl.col("gamma").mean()
    )
    meangammadfs.append(means.with_columns(replica=replica, wtime=time))
    summary = (
        pl.DataFrame(gammas)
            .describe()
            .with_columns(replica=replica, wtime=time)
            .pivot(on="statistic", values="column_0")
    ).with_columns(sample=np.expand_dims(gammas, 0))
    gammadfs.append(summary)
gammadf = pl.concat(gammadfs).sort("replica", "wtime")
meangammadf = pl.concat(meangammadfs)
meangammadf

# %%
# Simple gamma:
# wtimes = celldf["wtime"].sort().diff()
# wtime = wtimes.filter(wtimes != 0).mean()
# gammadfs = []
# meangammadfs = []
# groupped = (
#     celldf
#         .filter((pl.col("wtime") - wtime) % 2e6 == 0)  # Values only change between seasons of 2e6 steps
#         .group_by(["replica", "wtime"])
# )
# for (replica, time), group in tqdm(groupped):
#     means = group.with_columns(
#         mean_gamma=-pl.col("genome_val")
#     )
#     gammas = means["mean_gamma"].to_numpy()
#     meangammadfs.append(means.select("replica", "wtime", "mean_gamma", "index"))
#     summary = (
#         pl.DataFrame(gammas)
#             .describe()
#             .with_columns(replica=replica, wtime=time)
#             .pivot(on="statistic", values="column_0")
#     ).with_columns(sample=np.expand_dims(np.random.choice(gammas, 100), 0))
#     gammadfs.append(summary)
# gammadf = pl.concat(gammadfs).sort("replica", "wtime")
# meangammadf = pl.concat(meangammadfs).sort("replica", "wtime")
# meangammadf

# %%
# Local gamma:
# wtimes = celldf["wtime"].sort().diff()
# wtime = wtimes.filter(wtimes != 0).mean()
# selectors = ["index", "neighbors", "neighbor_gammas"]
# meangammadfs = []
# groupped = (
#     celldf
#         .filter((pl.col("wtime") - wtime) % 2e6 == 0)  # Values only change between seasons of 2e6 steps
#         .group_by(["replica", "wtime"])
# )
# for (replica, time), group in tqdm(groupped):
#     exdf = group.select(
#         selectors
#     ).with_columns(
#         pl.col("neighbors").str.split(" "),
#         pl.col("neighbor_gammas").str.split(" ")
#     ).explode([
#         "neighbors",
#         "neighbor_gammas"
#     ]).filter(
#         ~pl.col("neighbors").is_in(["s", "m"])
#     ).with_columns(
#         pl.col("neighbors").cast(int),
#         pl.col("neighbor_gammas").cast(int)
#     )
#     aggdf = exdf.group_by("index", maintain_order=True).agg(
#         pl.col("neighbors"),
#         pl.col("neighbor_gammas"),
#         mean_gamma=pl.col("neighbor_gammas").mean()
#     )
#     ind = np.arange(100)
#     ind = ind[~np.isin(ind, aggdf["index"])]
#     missdf = pl.DataFrame({
#         "index": ind.astype(np.uint32),
#         "neighbors": [[]] * len(ind),
#         "neighbor_gammas": [[]] * len(ind),
#         "mean_gamma": [None] * len(ind)
#     })
#     aggdf = pl.concat([aggdf, missdf]).with_columns(
#         replica=replica,
#         wtime=time
#     )
#     meangammadfs.append(aggdf)  

# gammadf = meangammadf.group_by("replica", "wtime").agg(
#     mean=pl.col("neighbor_gammas").flatten()
# ).with_columns(
#     pl.col("mean").list.filter(pl.element().is_finite()).list.mean()
# ).sort("replica", "wtime")
# meangammadf = pl.concat(meangammadfs).sort(
#     "replica", 
#     "wtime",
#     "mean_gamma"
# )
# meangammadf

# %%
def make_ancmelt(ancdf):
    return (
        ancdf
            # "lineage" is a unique identifier for leaf and corresponding ancestry path (both extinct and non-extinct)
            # "og" is the cell id of each lineage at the root (wtime == 0)
            # "id" is the cell id of the lineage at that time in the simulation
            .with_columns(lineage=np.arange(ancdf.height), og=ancdf["100000"])
            .unpivot(index=["lineage", "og"], value_name="index", variable_name="wtime")
            .with_columns(pl.col("wtime").cast(int))
            .sort(["lineage", "wtime"])
    )

# %%
ancmelts = []
dtrees = {}
for r in tqdm(range(celldf["replica"].max())):
    ancdf = phy.matrix(celldf.filter(replica=r), 2e6)
    rtrees = phy.trees(ancdf)
    dtrees[r] = rtrees
    melt = make_ancmelt(ancdf).with_columns(replica=r)
    ancmelts.append(melt)
ancmelt = pl.concat(ancmelts)
ancmelt

# %%
gammadesc = ancmelt.join(
    ancmelt.select("replica", "wtime", "lineage", "index"),
    left_on=["replica", "wtime", "lineage"],
    right_on=["replica", pl.col("wtime") - 2_000_000, "lineage"],
    suffix="_desc"
).unique(["replica", "wtime", "index", "index_desc"]).join(
    meangammadf,
    on=["replica", "wtime", "index"],
).sort("replica", "wtime", "index")
gammadesc

# %%
bins = np.linspace(0, 200e6, 15)
fitdf = gammadesc.group_by(
    "replica",
    "index",
    "wtime"
).agg(
    pl.col("mean_gamma").first(),
    gamma_check=pl.col("mean_gamma").n_unique(),
    n_desc=pl.len() - (pl.col("index_desc").null_count() == 1)
).with_columns(
    time_bin=pl.col("wtime").cut(bins[1:-1], labels=bins[:-1].round(2).astype("str")).cast(str).cast(float)
).drop_nans().sort("replica", "wtime", "mean_gamma")
assert (fitdf["gamma_check"] == 1).all()
fitdf

# %%
exdf = gammadf.explode("sample")
exdf

# %%
fig = px.histogram(
    exdf.filter(pl.col("mean") <= 0),
    x="sample",
    nbins=100,
    histnorm="probability",
).update_traces(
    marker_color=colors2[2],
    xbins=dict(start=-17, end=17, size=2)
).update_layout(
    width=350,
    height=250,
    template="plotly_white",
    xaxis_dtick=2,
    bargap=0.
)
io.save_plot(fig, "../plots/neg_gamma_distr")

# %%
fig = px.histogram(
    exdf.filter(pl.col("mean").is_between(-1, 1)),
    x="sample",
    nbins=100,
    histnorm="probability"
).update_traces(
    marker_color=colors2[2],
    xbins=dict(start=-17, end=17, size=2)
).update_layout(
    width=350,
    height=250,
    template="plotly_white",
    xaxis_dtick=2,
)
io.save_plot(fig, "../plots/zero_gamma_distr")

# %%
fig = px.histogram(
    exdf.filter(pl.col("mean").is_between(3, 5)),
    x="sample",
    nbins=100,
    histnorm="probability"
).update_traces(
    marker_color=colors2[2],
    xbins=dict(start=-17, end=17, size=2)
).update_layout(
    width=350,
    height=250,
    template="plotly_white",
    xaxis_dtick=2,
)
io.save_plot(fig, "../plots/4_gamma_distr")
fig

# %%
# Any single cells in a unicellular population are unlikely to evolve strong adhesion to the population, as show by how narrow the distribution is
# In contrast, when starting from an intermediate level of adhesion
fig = px.histogram(
    exdf.filter(pl.col("mean") <= 0),
    x="sample",
    nbins=100,
    histnorm="probability"
).add_traces(
    px.histogram(
        exdf.filter(pl.col("mean").is_between(2, 4)),
        x="sample",
        nbins=100,
        histnorm="probability"
    ).update_traces(
        marker_color=cl.StackPalette.load("plotly")[1]
    ).data
).update_traces(
    marker_opacity=0.5,
    xbins=dict(start=-17, end=17, size=2)
).update_layout(
    width=350,
    height=250,
    template="plotly_white",
    xaxis_dtick=2,
    barmode="overlay"
)
io.save_plot(fig, "../plots/gamma_distr")
fig

# %%
# However no cell seems to have a high gamma with the whole population, indicating that these connections
# are restricted to a subset of cell pairs
fig = px.histogram(
    fitdf.filter(pl.col("mean_gamma").mean().over("replica", "wtime") <= 0),
    x="mean_gamma",
    nbins=100,
    histnorm="probability"
).add_traces(
    px.histogram(
        fitdf.filter(pl.col("mean_gamma").mean().over("replica", "wtime").is_between(2, 4)),
        x="mean_gamma",
        nbins=100,
        histnorm="probability"
    ).update_traces(
        marker_color=cl.StackPalette.load("plotly")[1]
    ).data
).update_traces(
    marker_opacity=0.5,
).update_layout(
    width=350,
    height=250,
    template="plotly_white",
    xaxis_dtick=2,
    barmode="overlay"
)
io.save_plot(fig, "../plots/gamma_distr_mean")
fig

# %%
def concentration_stats(gammas):
    """
    Two-level concentration diagnostics for a pairwise measurement matrix.

    gammas : (N, N) array, gammas[i, j] = p for the pair (i, j).
             Values must be non-negative. NaN = unmeasured pair.

    Returns a dict with:
      N_eff        effective number of participating particles
      k_eff        (N,) effective number of partners per particle
      k_eff_mean   strength-weighted mean of k_eff
      ratio        k_eff_mean / N_eff  ->  ~1 for a clique, ~1/N for a matching
      strength     (N,) node strengths s_i
    """
    G = np.array(gammas, dtype=float)
    if G.ndim != 2 or G.shape[0] != G.shape[1]:
        raise ValueError("gammas must be square")

    G = np.nan_to_num(G, nan=0.0)
    if np.any(G < 0):
        raise ValueError("negative values: shift or transform p first")
    np.fill_diagonal(G, 0.0)

    s = G.sum(axis=1)                       # node strengths
    W = s.sum()
    if W <= 0:
        raise ValueError("all measurements are zero")

    # effective number of active particles (participation ratio on strengths)
    N_eff = s.sum() ** 2 / np.sum(s ** 2)

    # effective number of partners per particle
    denom = np.sum(G ** 2, axis=1)
    k_eff = np.divide(s ** 2, denom, out=np.zeros_like(s), where=denom > 0)

    # weight by strength so idle particles don't drag the mean around
    k_eff_mean = np.sum(s * k_eff) / W

    return {
        "N_eff": N_eff,
        "k_eff": k_eff,
        "k_eff_mean": k_eff_mean,
        "ratio": k_eff_mean / N_eff,
        "strength": s,
    }

# %%
gammadf

# %%
import matplotlib.pyplot as plt
from pyvis.network import Network
from matplotlib.colors import Normalize, to_hex

def draw_interactive(G, weight="weight", cmap=plt.cm.viridis,
                     out="graph.html", scale=1200, seed=1):
    values = [d[weight] for _, _, d in G.edges(data=True)]
    lo, hi = min(values), max(values)
    if lo == hi:
        raise ValueError(f"every edge has {weight}={lo!r}; nothing to colour by")
    norm = Normalize(vmin=lo, vmax=hi)

    pos = nx.spring_layout(G, seed=seed)

    net = Network(height="750px", width="100%", cdn_resources="in_line")
    for n in G.nodes():
        x, y = pos[n]
        net.add_node(n, label=str(n), size=10,
                     x=float(x * scale), y=float(y * scale))
    for u, v, d in G.edges(data=True):
        w = d[weight]
        net.add_edge(u, v, color=to_hex(cmap(norm(w))), width=3,
                     title=f"{weight} = {w:g}")

    net.set_options(
        '{"edges":{"smooth":false,"color":{"inherit":false}},'
        '"physics":{"enabled":false},'
        '"interaction":{"dragNodes":true,"hideEdgesOnDrag":true}}'
    )
    net.write_html(out, notebook=False)
    return out


def strong_edge_subgraph(G, threshold, weight="weight"):
    """Edges of G with weight >= threshold, isolated vertices dropped."""
    H = nx.Graph()
    H.add_edges_from(
        (u, v) for u, v, d in G.edges(data=True) if d.get(weight, 1.0) >= threshold
    )
    return H
 
 
def _largest_component(H):
    """Component of H holding the most edges (not the most vertices)."""
    comps = list(nx.connected_components(H))
    return max(comps, key=lambda c: H.subgraph(c).number_of_edges())
 
 
def S_density(G, threshold, weight="weight"):
    H = strong_edge_subgraph(G, threshold, weight)
    m = G.number_of_edges()
    n = G.number_of_nodes()
    cliques = list(nx.find_cliques(G))
    if cliques:
        cs = max(len(c) for c in cliques)
    else:
        cs = 0
    if H.number_of_edges() == 0:
        n1 = 1
        m1 = 0
        d = np.nan
    else:
        giant = H.subgraph(_largest_component(H))
        n1, m1 = giant.number_of_nodes(), giant.number_of_edges()
        d = 2 * m1 / (n1 * (n1 - 1))
    return n1, d, cs

# %%
import networkx as nx

d = {
    "replica": [],
    "wtime": [],
    "mean_gamma": [],
    "S": [],
    "density": [],
    "clique_size": [],
    "G": [],
}

for (r, t, gm, s) in tqdm(gammadf.select("replica", "wtime", "mean", "sample").rows()):
    sample = np.reshape(s, (100, 100))
    sample[np.arange(100), np.arange(100)] = 0
    sample[sample < 8] = 0
    G = nx.from_numpy_array(sample)
    S, density, cs = S_density(G, 8)
        
    d["replica"].append(r)
    d["wtime"].append(t)
    d["mean_gamma"].append(gm)
    d["S"].append(S)
    d["density"].append(density)
    d["clique_size"].append(cs)
    d["G"].append(G)
    
graphdf = pl.DataFrame(d)
graphdf

# %%
graphdf.filter(pl.col("mean_gamma").is_between(2, 4), pl.col("clique_size") > 60)

# %%
px.scatter(
    graphdf.filter(pl.col("wtime") > 5e6),
    x="mean_gamma",
    y="S"
)

# %%
px.scatter(
    graphdf.filter(pl.col("wtime") > 5e6),
    x="mean_gamma",
    y="density"
)

# %%
px.scatter(
    graphdf.filter(pl.col("wtime") > 5e6),
    x="mean_gamma",
    y="clique_size"
)

# %%
# There are some interesting "parapatric speciation" (not exactly) events shown here (see below)
fig = px.scatter(
    graphdf.filter(pl.col("replica") > -1),
    x="mean_gamma",
    y="clique_size",
    color="density",
    hover_data="wtime"
).update_layout(
    width=500,
    height=300,
    template="plotly_white",
    yaxis_range=[0, 100],
    xaxis_range=[-5, 16],
)
io.save_plot(fig, "../plots/graph_clique_density")

# %%
fig = px.line(
    graphdf.filter(pl.col("replica") > -1),
    x="mean_gamma",
    y="clique_size",
    color="replica",
    hover_data="wtime"
).update_layout(
    width=500,
    height=300,
    template="plotly_white",
    yaxis_range=[0, 100],
    xaxis_range=[-5, 16],
)
io.save_plot(fig, "../plots/graph_all_trajectories")

# %%
not_cliquey = graphdf.filter(
    pl.col("mean_gamma") > 5,
    pl.col("clique_size").max().over("replica") < 50
)["replica"].unique()
high_gamma = graphdf.filter(
    pl.col("mean_gamma").max().over("replica") > 10,
)["replica"].unique()

# %%
grad = cl.Grad(cl.StackPalette.load("plasma"), domain=[0, 200e6])
dashes = ['solid', 'dot', 'dash', 'longdash', 'dashdot', 'longdashdot']
fig = go.Figure()
for j, ((r,), group) in enumerate(
    graphdf.filter(
        pl.col("replica").is_in(set(high_gamma))
    ).group_by("replica")
):
    step = 2
    for i in range(0, group.height, step):
        rows = group[i:i + step + 1]
        time = rows[0, "wtime"]
        fig.add_trace(
            go.Scatter(
                x=rows["mean_gamma"],
                y=rows["clique_size"],
                line_color=grad(time),
                line_width=3,
                # opacity=0.5,
                line_dash="solid",
                mode="lines",
                hovertext=r
            )
        )
fig.update_layout(
    template="plotly_white",
    width=500,
    height=350,
    showlegend=False,
    yaxis_range=[0, 100],
    xaxis_range=[-5, 16],
    xaxis_title="mean_gamma",
    yaxis_title="clique_size"
)
io.save_plot(fig, "../plots/graph_evol_high_gamma")

# %%
fig = go.Figure()
for j, ((r,), group) in enumerate(
    graphdf.filter(
        pl.col("replica").is_in(set(not_cliquey).difference(high_gamma))
    ).group_by("replica")
):
    step = 2
    for i in range(0, group.height, step):
        rows = group[i:i + step + 1]
        time = rows[0, "wtime"]
        fig.add_trace(
            go.Scatter(
                x=rows["mean_gamma"],
                y=rows["clique_size"],
                line_color=grad(time),
                line_width=3,
                # opacity=0.5,
                line_dash="solid",
                mode="lines",
                hovertext=r
            )
        )
fig.update_layout(
    template="plotly_white",
    width=500,
    height=350,
    showlegend=False,
    yaxis_range=[0, 100],
    xaxis_range=[-5, 16],
    xaxis_title="mean_gamma",
    yaxis_title="clique_size"
)
io.save_plot(fig, "../plots/graph_evol_not_cliquey")

# %%
grad = cl.Grad(cl.StackPalette.load("plasma"), domain=[0, 100])
fig = go.Figure()
for j, ((r,), group) in enumerate(
    graphdf.filter(
        pl.col("replica").is_in(set(high_gamma))
    ).group_by("replica")
):
    step = 2
    for i in range(0, group.height, step):
        rows = group[i:i + step + 1]
        fig.add_trace(
            go.Scatter(
                x=rows["wtime"],
                y=rows["mean_gamma"],
                line_color=grad(rows[0, "clique_size"]),
                line_width=3,
                # opacity=0.5,
                line_dash="solid",
                mode="lines",
                hovertext=r
            )
        )
fig.update_layout(
    template="plotly_white",
    width=500,
    height=350,
    showlegend=False,
    xaxis_title="time",
    yaxis_title="mean_gamma"
)
io.save_plot(fig, "../plots/graph_evol_high_gamma_time")

# %%
gs = graphdf.filter(pl.col("wtime").is_between(36100000, 105e6), replica=19)["G"]
distrs = []
for g in gs:
    cs = [len(g) for g in nx.find_cliques(g)]
    distrs.append(sorted(cs)[-5:])

# %%
# For example, sim 19 seems to evolve to cell lineages at ~timestep 1e8 where within
# each cell lineage they are highly adherent but not across cell lineages, causing the cluster to split into two!
# Before splitting the cluster remains cohesive because some cells are adherent to both groups
fig = go.Figure()
grad = cl.Grad(cl.StackPalette.load("plasma"), domain=[0, len(distrs) - 1])
for i, distr in enumerate(distrs):
    fig.add_traces(go.Histogram(
        x=distr,
        marker_color=grad(i)
    ))
fig

# %%
def renorm(df):
    return df.with_columns(pl.col("len") / pl.col("len").sum())

lens = exdf.filter(
    pl.col("mean").is_between(2, 4)
).group_by(
    "sample"
).len().sort(
    "sample"
).select(
    pl.col("sample"),
    energy=20 - pl.col("sample"),
    len=pl.col("len") / pl.col("len").sum(),
)
lens

# %%
lt8 = lens.filter(pl.col("sample") < 8)
lt8["len"].sum()

# %%
renorm(lt8.drop("sample")).rows()

# %%
fitdf.group_by("replica", "wtime").agg(
    mean=pl.col("mean_gamma").mean()
).filter(
    # This seems to be about when the first cluster appears (so much before mean gamma = 8)
    pl.col("mean") >= 4
).group_by("replica").agg(
    first=pl.col("wtime").min()
).sort("replica")

# %%
def decimal_repr(bit_array):
    return np.dot(bit_array, 1 << np.arange(bit_array.shape[-1] - 1, -1, -1))


mut_rate = 0.01
mut_steps = 50
pop_size = 100_000
mut_genome = np.array([0] * 8 + [1] * 8, dtype=bool)
pop = np.tile(mut_genome, (pop_size, 1))
for _ in range(mut_steps):
    mut_mask = np.random.random((pop_size, 16)) < mut_rate
    pop = np.where(mut_mask, ~pop, pop)

pop_ligs = pop[:, :8]
pop_receps = pop[:, 8:]
gamma = adh.calculate_gamma(
    20, 
    adh.cell_contact_energy(
        np.zeros(pop_size, dtype=int),
        np.zeros(pop_size, dtype=int),
        decimal_repr(pop_ligs),
        decimal_repr(pop_receps),
        20,
        32,
        8
    )
)
px.histogram(gamma)

# %%
from scipy.special import comb

def success_prob(trials, prob):
    """
    Probability that a gene will end in a flipped state after many `trials` each with probability `prob`.
    """
    i = np.arange(1, trials + 1, 2)
    return np.sum(prob ** i * (1 - prob) ** (trials - i) * comb(trials, i))

def binom_pmf(k, n, p):
    return p ** k * (1 - p) ** (n - k) * comb(n, k)

def binom_tail(k, n, p):
    return np.sum([binom_pmf(i, n, p) for i in range(k, n + 1)])

def k_added(k, genome_size, comp, prob, trials):
    """
    Probability of obtaining k new complementary genes in `trials` many rounds of mutation, starting from 
    `comp` complementary genes.
    """
    non_comp = genome_size - comp
    assert non_comp >= k, "cannot gain this many complementary genes"

    p = success_prob(trials, prob)
    # For each complementary gene that flips into a mismatch, 
    # we need a compensating mutation in a non-compl gene + the necessary mutations to get to k
    return np.sum([binom_pmf(i, comp, p) * binom_tail(i + k, non_comp, p) for i in range(comp + 1)])

# %%
# Assuming that the population expresses a single bitstring against which the genome of each cell is tested,
# this shows the probability that a cell will have gamma >= 8 with the population after x generations
# This should converge towards the prob that any two random bitstrings have gamma >= 8 
# given by (binom_cum(12, 16, 0.5))
# I checked that it does indeed!
reach_gamma8 = {
    "gamma0": [],
    "gen": [],
    "prob": []
}
for comp in range(6, 10 + 1, 1):
    for gen in range(101):
        gamma0 = comp * 2 - 16
        reach_gamma8["gamma0"].append(gamma0)
        reach_gamma8["gen"].append(gen)
        reach_gamma8["prob"].append(k_added(int(-gamma0 / 2 + 4), 16, comp, 0.01, gen))

rgdf = pl.DataFrame(reach_gamma8)
fig = px.line(
    rgdf,
    x="gen",
    y="prob",
    color="gamma0",
    color_discrete_sequence=cl.StackPalette.load("sunset")[::-1].resize(rgdf["gamma0"].n_unique())
).update_layout(
    template="plotly_white",
    width=400,
    height=250,
    showlegend=False,
    xaxis_title="generation",
    yaxis_title="probability",
    xaxis_dtick=25
)
io.save_plot(fig, "../plots/mut_constraint")

# %%
px.histogram(fitdf.filter(replica=0), x="mean_gamma", y="n_desc", histfunc="avg", animation_frame="time_bin")

# %%
px.scatter(
    fitdf.filter(pl.col("wtime") > 150e6, replica=0).with_columns(w=pl.col("n_desc")),
    x="mean_gamma",
    y="w",
    opacity=0.5,
    trendline="ols"
)

# %%
import numpy as np
from scipy.optimize import minimize_scalar


def compute_bounds(t, N):
    pos = t[t > 0]
    neg = t[t < 0]
    upper_candidates = []
    lower_candidates = []
    if pos.size > 0:
        upper_candidates.append(np.min((1 - 1/N) / pos))
        lower_candidates.append(np.max(-1 / (N * pos)))
    if neg.size > 0:
        upper_candidates.append(np.min(-1 / (N * neg)))
        lower_candidates.append(np.max((1 - 1/N) / neg))
    upper = min(upper_candidates)
    lower = max(lower_candidates)
    return lower, upper


def neg_log_likelihood(a, W, t, N):
    p = 1 / N + t * a
    if np.any(p <= 0) or np.any(p >= 1):
        return np.inf
    # Multinomial log-likelihood (coefficient dropped, constant in a)
    return -np.sum(W * np.log(p))


def estimate_a(W, t, N):
    lower_bound, upper_bound = compute_bounds(t, N)
    result = minimize_scalar(
        neg_log_likelihood,
        bounds=(lower_bound, upper_bound),
        method='bounded',
        args=(W, t, N)
    )
    return result.x, lower_bound, upper_bound


def se_a_fisher(a_hat, t, N):
    p = 1 / N + t * a_hat
    fisher_info = N * np.sum(t**2 / p)
    return 1 / np.sqrt(fisher_info)

As = []
for (replica, time), group in fitdf.group_by(["replica", "wtime"]):
    t = np.array(group["mean_gamma"])
    # Clip assuming that all negative gamma behaves the same
    # t = np.clip(t, 0, None)
    # Standardize the trait
    t = (t - np.mean(t)) / np.std(t, ddof=1)
    W = np.array(group["n_desc"])

    N = 100
    assert len(group) == N
    assert W.sum() == N

    a, a_low, a_high = estimate_a(W, t, N)
    se = se_a_fisher(a, t, N)
    As.append((replica, time, a, a_low, a_high, se))

multidf = pl.from_records(
    As,
    schema=("replica", "wtime", "coeff", "a_low", "a_high", "se"),
    orient="row"
).sort("replica", "wtime")
multidf

# %%
from scipy.stats import linregress

def estimate_beta_cov(W, t):
    result = linregress(t, W)
    return result.slope, result.stderr  # selection gradient (beta), SE

def selection_differential(W, t):
    return np.cov(t, W, ddof=1)[0, 1]  # S = cov(trait, relative fitness)

As = []
for (replica, time), group in fitdf.group_by(["replica", "wtime"]):
    t = np.array(group["mean_gamma"])
    # Clip assuming that all negative gamma behaves the same
    # t = np.clip(t, 0, None)
    # Standardize the trait
    t = (t - np.mean(t)) / np.std(t, ddof=1)
    if np.isnan(t).all():
        continue
    W = np.array(group["n_desc"])
    # This shouldnt matter bc the pop size is const
    W = W / np.mean(W)
    assert np.isclose(np.mean(t), 0)
    assert np.isclose(np.mean(W), 1)
    assert W.sum() == N
    beta, se = estimate_beta_cov(W, t)
    As.append((replica, time, beta, se))

covdf = pl.from_records(
    As,
    schema=("replica", "wtime", "coeff", "se"),
    orient="row"
).sort("replica", "wtime").with_columns(
    roll_coeff=pl.col("coeff").rolling_mean(window_size=5).over("replica")
)
covdf

# %%
def make_coeff_fig(coeffdf, se, rolling_window_size=1):
    fig = make_subplots(
        2, 
        2,
        row_heights=[0.55, 0.45], 
        column_widths=[0.85, 0.15], 
        shared_yaxes=True,
        shared_xaxes=True, 
        horizontal_spacing=0.01,
        vertical_spacing=0.08
    )
    runs = [0, 5, 4]
    for (replica,), group in gammadf.filter(~pl.col("replica").is_in(runs)).sort("wtime").group_by("replica", maintain_order=True):
        color = colors[7]
        line = go.Scatter(
            x=group["wtime"],
            y=group["mean"],
            # Lines or markers
            mode="lines",
            line_color=color,
            line_width=6,
            opacity=0.08,
            legendgroup=replica,
            name=replica,
            marker_size=8
            # visible="legendonly"
        )
        fig.add_trace(line, row=1, col=1)
    fig.add_traces(px.line(
        gammadf.filter(pl.col("replica").is_in(runs)),
        x="wtime",
        y="mean",
        color="replica",
        color_discrete_sequence=colors2
    ).update_traces(
        line_width=4,
        # visible="legendonly"
    ).data, rows=1, cols=1)

    rolldf = coeffdf.filter(
        pl.col("replica").is_in(runs)
    ).sort(
        "wtime"
    ).with_columns(
        pl.col("coeff").rolling_mean(window_size=rolling_window_size).over("replica")
    )
    fig.add_traces(px.line(
        rolldf,
        x="wtime",
        y="coeff",
        color="replica",
        color_discrete_sequence=colors2,
        error_y=se
    ).update_traces(
        # visible="legendonly"
    ).data, rows=2, cols=1)
    
    fig.add_trace(go.Histogram(
        y=gammadf.filter(wtime=pl.col("wtime").max())["mean"],
        nbinsy=12,
        marker_color="#999999"
    ), row=1, col=2)
    
    fig.update_layout(
        template="plotly_white",
        yaxis_title="mean gamma",
        width=700,
        height=550,
        bargap=0.1,
        showlegend=False
    )
    fig.update_xaxes(
        title="time",
        row=2
    )
    fig.update_xaxes(
        showgrid=False,
        showticklabels=False,
        col=2
    )
    fig.update_yaxes(
        showgrid=False,
        col=2
    )
    fig.update_yaxes(
        title="coeff",
        row=2
    )
    fig.update_xaxes(tickangle=0)
    return fig

# %%
fig = make_coeff_fig(covdf, None, 5)
io.save_plot(fig, "../plots/adhesion_evolution")
fig

# %%
# We can replicate the results using the multinomial
make_coeff_fig(multidf, None, 5)

# %%
multimesdf = covdf.join(
    gammadf.with_columns(
        # We use this later to infer the interval in which adhesion is increasing
        gamma_level=(
            pl.when(pl.col("mean") > 10)
                .then(pl.lit("high"))
                .otherwise(
                    pl.when(pl.col("mean") <= 0)
                        .then(pl.lit("neg"))
                        .otherwise(pl.lit("low"))
                )
        ).cast(pl.Enum(("neg", "low", "high"))),
        gamma_sign=(
            pl.when(pl.col("mean") > 0)
                .then(pl.lit("pos"))
                .otherwise(
                    pl.lit("neg")
                )
        ).cast(pl.Enum(("neg", "pos")))
    ),
    on=["replica", "wtime"]
).sort(
    "replica", 
    "wtime"
).with_columns(
    gamma_bin=pl.col("mean").cut(np.arange(-16, 20, 2), include_breaks=True).struct.field("breakpoint"),
)
multimesdf

# %%
from statsmodels.stats.weightstats import ttest_ind
from itertools import combinations

boxcolors = cl.StackPalette.load("safe")
fig = px.box(
    # Ensure independent measurements (unlike the rolling window)
    multimesdf.sort("gamma_sign"),
    y="roll_coeff",
    x="gamma_sign", 
    color_discrete_sequence=boxcolors,
    notched=True,
)
fig.update_traces(
    marker_line_width=1,
    marker_line_color="white",
    marker_color=boxcolors[0],
    marker_opacity=0.5,
    jitter=0.5
)
fig.update_layout(
    template="plotly_white",
    width=300,
    height=320,
    xaxis_title="mean gamma"
)

levels = combinations(multimesdf["gamma_sign"].unique(), 2)
ps = {0.05: "*", 0.01: "**", 0.001: "***"}
for i, (level1, level2) in enumerate(levels):
    y = 0.3 + i * 0.05
    g1 = multimesdf.filter(gamma_sign=level1)["coeff"]
    g2 = multimesdf.filter(gamma_sign=level2)["coeff"]
    _, p, _ = ttest_ind(g1, g2)
    lab = "ns"
    if p < 0.05:
        lab = "*"
    if p < 0.01:
        lab = "**"
    if p< 0.001:
        lab = "***"
    fig.add_shape(
        type="line",
        x0=level1,
        x1=level2,
        y0=y,
        y1=y,
        line_width=1
    )
    fig.add_annotation(
        x=level1,
        y=y + 0.005,
        text=lab,
        showarrow=False,
        font={"size": 14}
    )

io.save_plot(fig, "../plots/a_coeff_box")

# %%
binsdf = multimesdf.group_by("gamma_bin").agg(
    pl.col("coeff").mean(),
    pl.len()
).filter(pl.col("len") >= 30)
fig = px.bar(
    binsdf,
    x="gamma_bin",
    y="coeff"
).update_traces(
    marker_color=colors2[2]
).update_layout(
    bargap=0.1,
    template="plotly_white",
    width=400,
    height=300,
    xaxis_dtick=2,
    xaxis_title="gamma"
)
io.save_plot(fig, "../plots/coeff_bars")

# %%
fig = px.histogram(
    multimesdf,
    x="mean",
    y="coeff",
    histfunc="avg",
    nbins=5
).update_traces(
    marker_color=colors2[2]
).update_layout(
    bargap=0.1,
    template="plotly_white",
    width=400,
    height=300,
    xaxis_dtick=5,
    xaxis_title="gamma"
)
io.save_plot(fig, "../plots/coeff_histogram")

# %%
muldf = multimesdf.filter(
    # Filter runs that didnt become mult
    ((pl.col("gamma_level") == "high") & (pl.col("wtime") == pl.col("wtime").max())).any().over("replica")
).sort("wtime").with_columns(
    rle_id=pl.col("gamma_level").rle_id().over("replica"),
).group_by("replica", "rle_id").agg(
    rle=pl.len(),
    gamma_level=pl.first("gamma_level"),
    midtime=(pl.col("wtime").min() + pl.col("wtime").max()) / 2
).filter(
    rle=pl.col("rle").filter(pl.col("gamma_level") == "low").max().over("replica")
).join(
    covdf.filter(roll_coeff=pl.col("roll_coeff").max().over("replica")),
    on=["replica"]
).sort("wtime")
muldf

# %%
import statsmodels.api as sm

X = sm.add_constant(muldf["wtime"].to_numpy())
model = sm.OLS(muldf["midtime"].to_numpy(), X).fit()
predictions = model.get_prediction(X)
summary = predictions.summary_frame(alpha=0.05)
print(model.summary(alpha=0.05))

fig = px.scatter(
    muldf,
    x="wtime", 
    y="midtime",
    hover_name="replica",
)
fig.update_traces(
    zorder=3,
    marker_color=boxcolors[0]
)
fig.add_traces([
    # go.Scatter(
    #     x=pl.concat([muldf["wtime"], muldf["wtime"][::-1]]),
    #     y=np.concatenate([summary["mean_ci_lower"], summary["mean_ci_upper"][::-1]]),
    #     fill="toself",
    #     line_color="rgba(0, 0, 0, 0)",
    #     opacity=0.2
    # ),
    go.Scatter(
        x=muldf["wtime"],
        y=summary["mean"],
        line_color="black"
    )
])
fig.update_layout(
    template="plotly_white",
    width=350,
    height=300,
    xaxis_title="time of peak a",
    yaxis_title="time of transition to mul.",
    showlegend=False,
    title=f"r^2: {model.rsquared}"
)
io.save_plot(fig, "../plots/peak_a-transition")

# %%
latdf = pl.read_parquet("../runs/evo/*/lattices/*.parquet", include_file_paths="path")
latdf

# %%
from analyses.rust import contact

ndfs = []
for (path,), lat in latdf.group_by("path"):
    lat = lat.select(pl.exclude("path"))
    nm = contact.neighbour_map(lat)
    path_list = path.split("/")
    time = int(path_list[-1].replace(".parquet", ""))
    replica = int(path_list[-3])
    ndf = pl.DataFrame({"index": nm.keys(), "neighbors": nm.values()}).with_columns(
        time=time,
        replica=replica,
        gamma=gamma
    )
    ndfs.append(ndf)
    
ndf = pl.concat(ndfs)
ndf = ndf.filter(~pl.col("index").is_in(["m", "s"])).with_columns(index=pl.col("index").cast(int))
ndf

# %%
ncelldf = ndf.join(celldf, on=["index", "time", "replica"]).sort("replica", "time", "index")
ncelldf

# %%
px.line(ancmelt, x="index", y="wtime", color="lineage").update_traces(visible="legendonly")

# %%
descdf = ancmelt.group_by(["og", "wtime"]).agg(n_descendents=pl.col("index").drop_nulls().n_unique()).sort("og", "wtime")
descdf

# %%
# First common ancestor of whole pop at wtime = 58e6
px.bar(
    descdf,
    x="wtime", 
    y="n_descendents", 
    color="og",
    barmode="stack"
).update_traces(
    marker_line_color="rgba(0, 0, 0, 0)"
).update_layout(
    bargap=0
)
